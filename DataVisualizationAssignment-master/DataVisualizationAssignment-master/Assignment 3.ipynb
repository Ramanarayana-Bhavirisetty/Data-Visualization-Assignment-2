# %% [markdown]
# # Data Visualization Assignment

# %%
#importing libraries
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = [20, 5]

# %%
import pandas as pd

# %%
#reading the dataset

# %%
data = pd.read_csv('GamingCompanies-Main.csv')

# %%
#Printing the Head of dataset
display(data.head(10))
# Out:
#                   Name     marketcap    earnings  employeeCount  \
# 0       11 bit studios  2.600171e+08     8147710            192
# 1  Activision Blizzard  5.835960e+10  2972000000           9500
# 2             Appirits  3.008261e+07     1591300            411
# 3           Aristocrat  1.551363e+10   778411000           7000
# 4                ATARI  4.923000e+07   -13476800             26
# 5         Bandai Namco  1.500087e+10   855030000           9550
# 6             Blue Hat  8.222565e+06    12263800            110
# 7            Bushiroad  3.286717e+08    24925400            620
# 8               Capcom  5.055709e+09   421968000           3152
# 9           CD Projekt  2.057000e+09    56327200           1177
#
#    OperatingMargin   PERatio       Revenue        country
# 0         4583.070  40.88810  1.777785e+07         Poland
# 1         3582.020  23.47170  8.297000e+09  United States
# 2          372.253  31.00000  4.274776e+07          Japan
# ...

# %%
#Scatter Plot using dataset

# %%
plt.scatter(data.head(10)['Name'],data.head(10)['earnings'])
plt.title("Scatter Plot")
plt.xlabel('Company')
plt.ylabel('Earnings')
# Out:
# Text(0, 0.5, 'Earnings')

# %%
#Bar Chart using the Data Set

# %%
plt.bar(data.head(10)['Name'],data.head(10)['earnings'])
plt.title("Bar Chart")
plt.xlabel("Company")
plt.ylabel("Earnings")
# Out:
# Text(0, 0.5, 'Earnings')

# %%
#Histogram using the DataSet

# %%
plt.hist(data.head(50)['earnings'])
plt.title("Histogram")
# Out:
# Text(0.5, 1.0, 'Histogram')

# %%
#line Plot using python on dataset

# %%
plt.plot(data.head(15)['Name'],data.head(15)['earnings'],linestyle='dashed',color='red')

# %%
#Double Line Plot on same Graph
plt.plot(data.head(13)['Name'],data.head(13)['OperatingMargin'],linestyle='dashed',color='red')
plt.plot(data.head(13)['Name'],data.head(13)['employeeCount'],linestyle='dashed',color='blue')

# %%
labels = data.head(13)['Name']
sizes = data.head(13)['employeeCount']
fig1,ax1 = plt.subplots()
ax1.pie(sizes,labels = labels,autopct = '%1.1f%%',shadow=True,startangle=90)
ax1.axis('equal')
plt.show()
